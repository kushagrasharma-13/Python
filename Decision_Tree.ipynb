# %% [markdown]
# <a href="https://colab.research.google.com/github/kushagrasharma-13/Python/blob/main/Decision_Tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Decision Tree Classification on Iris Data-set
#
# Correlation
#
# Classification Report
#
# Accuracy
#
# Confusion Matrix

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# %%
# Load "Iris.csv" dataset
dataset = pd.read_csv('/content/drive/MyDrive/Python/Datasets/Iris.csv')
dataset
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
dataset.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
corr = dataset.corr()
corr.style.background_gradient(cmap = 'coolwarm')
# Out:
# <ipython-input-6-ffd37e1235a7>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = dataset.corr()
# <style type="text/css">
# #T_b4d43_row0_col0, #T_b4d43_row1_col1, #T_b4d43_row2_col2, #T_b4d43_row3_col3, #T_b4d43_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b4d43_row0_col1 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_b4d43_row0_col2 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_b4d43_row0_col3, #T_b4d43_row3_col0 {
#   background-color: #d1493f;
#   color: #f1f1f1;
# }
# #T_b4d43_row0_col4, #T_b4d43_row4_col0 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_b4d43_row1_col0 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_b4d43_row1_col2 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_b4d43_row1_col3 {
# ...

# %%
ele = ["Iris-setosa", "Iris-versicolor", "Iris-virginica"]

# %% [markdown]
# # Length:

# %% [markdown]
# Sepal Length -->

# %%
plt.figure(figsize=(8,8))
plt.hist(dataset['SepalLengthCm'], color='yellow')
plt.title('Distribution of Sepal Length')
plt.xlabel('Sepal Length')
plt.show()
print("------------------------------------------------------------------------")

x_sl = dataset[['SepalLengthCm']]
y_sl = dataset[['Species']]
x_sl_train, x_sl_test, y_sl_train, y_sl_test = train_test_split(x_sl, y_sl, test_size=0.25, random_state=3)

DTC_sl = DecisionTreeClassifier()
DTC_sl.fit(x_sl_train, y_sl_train)
y_sl_pred = DTC_sl.predict(x_sl_test)

print("Classification Report: ")
print(classification_report(y_sl_test, y_sl_pred))
print("------------------------------------------------------------------------")


print("Accuracy: {:.2f}%".format(accuracy_score(y_sl_test, y_sl_pred)*100))
print("------------------------------------------------------------------------")

print("Confusion Matrix: ")
cm_sl = confusion_matrix(y_sl_test, y_sl_pred)
sns.heatmap(cm_sl,annot=True, xticklabels=ele, yticklabels=ele)
# Out:
# ------------------------------------------------------------------------
# Classification Report:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       0.93      0.87      0.90        15
# Iris-versicolor       0.40      0.33      0.36        12
#  Iris-virginica       0.43      0.55      0.48        11
#
#        accuracy                           0.61        38
#       macro avg       0.59      0.58      0.58        38
#    weighted avg       0.62      0.61      0.61        38
#
# ------------------------------------------------------------------------
# Accuracy: 60.53%
# ------------------------------------------------------------------------
# Confusion Matrix:
# <Axes: >

# %% [markdown]
# Petal Length -->

# %%
plt.figure(figsize=(8,8))
plt.hist(dataset['PetalLengthCm'], color='yellow')
plt.title('Distribution of Petal Length')
plt.xlabel('Petal Length')
plt.show()
print("------------------------------------------------------------------------")

x_pl = dataset[['PetalLengthCm']]
y_pl = dataset[['Species']]
x_pl_train, x_pl_test, y_pl_train, y_pl_test = train_test_split(x_pl, y_pl, test_size=0.25, random_state=3)

DTC_pl = DecisionTreeClassifier()
DTC_pl.fit(x_pl_train, y_pl_train)
y_pl_pred = DTC_pl.predict(x_pl_test)

print("Classification Report: ")
print(classification_report(y_pl_test, y_pl_pred))
print("------------------------------------------------------------------------")


print("Accuracy: {:.2f}%".format(accuracy_score(y_pl_test, y_pl_pred)*100))
print("------------------------------------------------------------------------")

print("Confusion Matrix: ")
cm_pl = confusion_matrix(y_pl_test, y_pl_pred)
sns.heatmap(cm_pl,annot=True, xticklabels=ele, yticklabels=ele)
# Out:
# ------------------------------------------------------------------------
# Classification Report:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        15
# Iris-versicolor       0.91      0.83      0.87        12
#  Iris-virginica       0.83      0.91      0.87        11
#
#        accuracy                           0.92        38
#       macro avg       0.91      0.91      0.91        38
#    weighted avg       0.92      0.92      0.92        38
#
# ------------------------------------------------------------------------
# Accuracy: 92.11%
# ------------------------------------------------------------------------
# Confusion Matrix:
# <Axes: >

# %% [markdown]
# Petal and Sepal Length

# %%
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.hist(dataset['SepalLengthCm'], color='yellow')
plt.title('Distribution of Sepal Length')
plt.xlabel('Sepal Length')
plt.subplot(1,2,2)
plt.hist(dataset['PetalLengthCm'], color='red')
plt.title('Distribution of Petal Length')
plt.xlabel('Petal Length')
plt.show()
print("------------------------------------------------------------------------")


x_pl_sl = dataset[['PetalLengthCm', 'SepalLengthCm']]
y_pl_sl = dataset[['Species']]

x_pl_sl_train, x_pl_sl_test, y_pl_sl_train, y_pl_sl_test = train_test_split(x_pl_sl, y_pl_sl, test_size=0.25, random_state=3)

DTC_pl_sl = DecisionTreeClassifier()
DTC_pl_sl.fit(x_pl_sl_train, y_pl_sl_train)
y_pl_sl_pred = DTC_pl_sl.predict(x_pl_sl_test)

print("Classification Report: ")
print(classification_report(y_pl_sl_test, y_pl_sl_pred))
print("------------------------------------------------------------------------")


print("Accuracy: {:.2f}%".format(accuracy_score(y_pl_sl_test, y_pl_sl_pred)*100))
print("------------------------------------------------------------------------")

print("Confusion Matrix: ")
cm_pl_sl = confusion_matrix(y_pl_sl_test, y_pl_sl_pred)
sns.heatmap(cm_pl_sl, annot=True, xticklabels=ele, yticklabels=ele)
# Out:
# ------------------------------------------------------------------------
# Classification Report:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        15
# Iris-versicolor       0.90      0.75      0.82        12
#  Iris-virginica       0.77      0.91      0.83        11
#
#        accuracy                           0.89        38
#       macro avg       0.89      0.89      0.88        38
#    weighted avg       0.90      0.89      0.89        38
#
# ------------------------------------------------------------------------
# Accuracy: 89.47%
# ------------------------------------------------------------------------
# Confusion Matrix:
# <Axes: >

# %% [markdown]
# # Width

# %% [markdown]
# Sepal Width -->

# %%
plt.figure(figsize=(8,8))
plt.hist(dataset['SepalWidthCm'], color='yellow')
plt.title('Distribution of Sepal Width')
plt.xlabel('Sepal Width')
plt.show()
print("------------------------------------------------------------------------")

x_sw = dataset[['SepalWidthCm']]
y_sw = dataset[['Species']]
x_sw_train, x_sw_test, y_sw_train, y_sw_test = train_test_split(x_sw, y_sw, test_size=0.25, random_state=3)

DTC_sw = DecisionTreeClassifier()
DTC_sw.fit(x_sw_train, y_sw_train)
y_sw_pred = DTC_sw.predict(x_sw_test)

print("Classification Report: ")
print(classification_report(y_sw_test, y_sw_pred))
print("------------------------------------------------------------------------")


print("Accuracy: {:.2f}%".format(accuracy_score(y_sw_test, y_sw_pred)*100))
print("------------------------------------------------------------------------")

print("Confusion Matrix: ")
cm_sw = confusion_matrix(y_sw_test, y_sw_pred)
sns.heatmap(cm_sw,annot=True, xticklabels=ele, yticklabels=ele)
# Out:
# ------------------------------------------------------------------------
# Classification Report:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       0.60      0.60      0.60        15
# Iris-versicolor       0.50      0.42      0.45        12
#  Iris-virginica       0.31      0.36      0.33        11
#
#        accuracy                           0.47        38
#       macro avg       0.47      0.46      0.46        38
#    weighted avg       0.48      0.47      0.48        38
#
# ------------------------------------------------------------------------
# Accuracy: 47.37%
# ------------------------------------------------------------------------
# Confusion Matrix:
# <Axes: >

# %% [markdown]
# Petal Width

# %%
plt.figure(figsize=(8,8))
plt.hist(dataset['PetalWidthCm'], color='yellow')
plt.title('Distribution of Petal Width')
plt.xlabel('Petal Width')
plt.show()
print("------------------------------------------------------------------------")

x_pw = dataset[['PetalWidthCm']]
y_pw = dataset[['Species']]
x_pw_train, x_pw_test, y_pw_train, y_pw_test = train_test_split(x_pw, y_pw, test_size=0.25, random_state=3)

DTC_pw = DecisionTreeClassifier()
DTC_pw.fit(x_pw_train, y_pw_train)
y_pw_pred = DTC_pw.predict(x_pw_test)

print("Classification Report: ")
print(classification_report(y_pw_test, y_pw_pred))
print("------------------------------------------------------------------------")


print("Accuracy: {:.2f}%".format(accuracy_score(y_pw_test, y_pw_pred)*100))
print("------------------------------------------------------------------------")

print("Confusion Matrix: ")
cm_pw = confusion_matrix(y_pw_test, y_pw_pred)
sns.heatmap(cm_pw,annot=True, xticklabels=ele, yticklabels=ele)
# Out:
# ------------------------------------------------------------------------
# Classification Report:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        15
# Iris-versicolor       0.92      0.92      0.92        12
#  Iris-virginica       0.91      0.91      0.91        11
#
#        accuracy                           0.95        38
#       macro avg       0.94      0.94      0.94        38
#    weighted avg       0.95      0.95      0.95        38
#
# ------------------------------------------------------------------------
# Accuracy: 94.74%
# ------------------------------------------------------------------------
# Confusion Matrix:
# <Axes: >

# %% [markdown]
# Petal and Sepal Width

# %%
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.hist(dataset['SepalWidthCm'], color='orange')
plt.title('Distribution of Sepal Width')
plt.xlabel('Sepal Width')
plt.subplot(1,2,2)
plt.hist(dataset['PetalWidthCm'], color='brown')
plt.title('Distribution of Petal Width')
plt.xlabel('Petal Width')
plt.show()
print("------------------------------------------------------------------------")

x_pw_sw = dataset[['PetalWidthCm', 'SepalWidthCm']]
y_pw_sw = dataset[['Species']]

x_pw_sw_train, x_pw_sw_test, y_pw_sw_train, y_pw_sw_test = train_test_split(x_pw_sw, y_pw_sw, test_size=0.25, random_state=3)

DTC_pw_sw = DecisionTreeClassifier()
DTC_pw_sw.fit(x_pw_sw_train, y_pw_sw_train)
y_pw_sw_pred = DTC_pw_sw.predict(x_pw_sw_test)

print("Classification Report: ")
print(classification_report(y_pw_sw_test, y_pw_sw_pred))
print("------------------------------------------------------------------------")


print("Accuracy: {:.2f}%".format(accuracy_score(y_pw_sw_test, y_pw_sw_pred)*100))
print("------------------------------------------------------------------------")

print("Confusion Matrix: ")
cm_pw_sw = confusion_matrix(y_pw_sw_test, y_pw_sw_pred)
sns.heatmap(cm_pw_sw,annot=True, xticklabels=ele, yticklabels=ele)
# Out:
# ------------------------------------------------------------------------
# Classification Report:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        15
# Iris-versicolor       0.92      0.92      0.92        12
#  Iris-virginica       0.91      0.91      0.91        11
#
#        accuracy                           0.95        38
#       macro avg       0.94      0.94      0.94        38
#    weighted avg       0.95      0.95      0.95        38
#
# ------------------------------------------------------------------------
# Accuracy: 94.74%
# ------------------------------------------------------------------------
# Confusion Matrix:
# <Axes: >
