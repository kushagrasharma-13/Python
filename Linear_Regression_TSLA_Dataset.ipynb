# %% [markdown]
# <a href="https://colab.research.google.com/github/kushagrasharma-13/Python/blob/main/Linear_Regression_TSLA_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Python/Datasets/TSLA.csv', low_memory=False)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2416 entries, 0 to 2415
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    2416 non-null   object
#  1   Open    2416 non-null   float64
#  2   High    2416 non-null   float64
#  3   Low     2416 non-null   float64
#  4   Close   2416 non-null   float64
#  5   Volume  2416 non-null   int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 113.4+ KB

# %%
dataset.head()
# Out:
#          Date       Open   High        Low      Close    Volume
# 0  29-06-2010  19.000000  25.00  17.540001  23.889999  18766300
# 1  30-06-2010  25.790001  30.42  23.299999  23.830000  17187100
# 2  01-07-2010  25.000000  25.92  20.270000  21.959999   8218800
# 3  02-07-2010  23.000000  23.10  18.709999  19.200001   5139800
# 4  06-07-2010  20.000000  20.00  15.830000  16.110001   6866900

# %%
dataset.isna().sum()
# Out:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
dataset_max_scaled = dataset.iloc[:, 1:]

# apply normalization techniques
for column in dataset_max_scaled.columns:
    dataset_max_scaled[column] = dataset_max_scaled[column]  / dataset_max_scaled[column].abs().max()

# view normalized data
display(dataset_max_scaled)
# Out:
#           Open      High       Low     Close    Volume
# 0     0.028203  0.031801  0.026042  0.030628  0.398732
# 1     0.038282  0.038695  0.034594  0.030551  0.365178
# 2     0.037109  0.032971  0.030096  0.028154  0.174627
# 3     0.034140  0.029384  0.027779  0.024615  0.109206
# 4     0.029687  0.025441  0.023503  0.020654  0.145902
# ...        ...       ...       ...       ...       ...
# 2411  0.843845  0.733724  0.828602  0.726795  0.250473
# 2412  0.854533  0.750248  0.842484  0.744859  0.378232
# 2413  0.938740  0.827944  0.917567  0.821551  0.616290
# 2414  0.949992  0.830641  0.939126  0.834064  0.333991
# 2415  1.000000  1.000000  1.000000  1.000000  1.000000
#
# [2416 rows x 5 columns]

# %%
x = dataset_max_scaled[['High', 'Low', 'Volume']]
y_open = dataset_max_scaled['Open']
y_close = dataset_max_scaled['Close']

# %%
x_train, x_test = train_test_split(x)
y_open_train, y_open_test = train_test_split(y_open)
y_close_train, y_close_test = train_test_split(y_close)

# %%
lr_open = LinearRegression()
lr_open.fit(x_train, y_open_train)
y_open_pred = lr_open.predict(x_test)

print("Coefficient (open): ", lr_open.coef_[0])
print("Intercept (open): ", lr_open.intercept_)
print("Mean Squared Error (open): ", mean_squared_error(y_open_test, y_open_pred))
print("R2_Score (open): ", r2_score(y_open_test, y_open_pred))
# Out:
# Coefficient (open):  -1.9091579725890626
# Intercept (open):  0.2680899418468696
# Mean Squared Error (open):  0.02902232271758192
# R2_Score (open):  0.0034745314567341534

# %%
lr_close = LinearRegression()
lr_close.fit(x_train, y_close_train)
y_close_pred = lr_close.predict(x_test)

print("Coefficient (close): ", lr_close.coef_[0])
print("Intercept (close): ", lr_close.intercept_)
print("Mean Squared Error (close): ", mean_squared_error(y_close_test, y_close_pred))
print("R2_Score (close): ", r2_score(y_close_test, y_close_pred))
# Out:
# Coefficient (close):  -1.3021150337978826
# Intercept (close):  0.24567542482187635
# Mean Squared Error (close):  0.023389460945372306
# R2_Score (close):  -0.004771701014390395
